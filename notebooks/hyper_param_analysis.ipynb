# %%
import torch
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm

# %%
distance = [
    [87.88, 87.97, 87.83], # addition 0.9-1
    [88.34, 88.57, 88.25], # addition 0.93-1
    [88.91, 88.90, 88.97], # addition 0.95-1

    [80.49, 80.32, 80.45], # addition 0.9-2
    [80.59, 80.91, 80.76], # addition 0.93-2
    [80.67, 80.59, 80.86], # addition 0.95-2

    [91.84, 91.42, 92.05], # multiplication 0.9-1
    [91.66, 91.99, 91.69], # multiplication 0.93-1
    [92.96, 92.84, 94.06], # multiplication 0.95-1

    [82.64, 82.77, 82.65], # multiplication 0.9-2
    [83.58, 83.57, 83.02], # multiplication 0.93-2
    [82.76, 82.72, 83.51], # multiplication 0.95-2
]

labels = [
    "addition - lambda: 0.9 - gamma: 1",
    "addition - lambda: 0.93 - gamma: 1",
    "addition - lambda: 0.95 - gamma: 1",

    "addition - lambda: 0.9 - gamma: 2",
    "addition - lambda: 0.93 - gamma: 2",
    "addition - lambda: 0.95 - gamma: 2",

    "multiplication - lambda: 0.9 - gamma: 1",
    "multiplication - lambda: 0.93 - gamma: 1",
    "multiplication - lambda: 0.95 - gamma: 1",

    "multiplication - lambda: 0.9 - gamma: 2",
    "multiplication - lambda: 0.93 - gamma: 2",
    "multiplication - lambda: 0.95 - gamma: 2",
]

# %%
for i in range(len(distance)):
    data = np.array(distance[i])
    label = labels[i]
    plt.plot(data, label=label, linestyle='-' if i < 6 else '--')

plt.title("InsBank data inter-distance")
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1.0), borderaxespad=0.)
plt.show()

# %%
global_distance = np.array([88.97,89.01,88.93,86.00,85.92,85.99,89.11,89.20,88.99,85.96,86.03,86.05,89.24,89.24,89.26,85.85,85.81,85.92,90.67,90.46,90.76,86.69,86.71,86.69,90.48,90.62,90.55,86.95,86.94,86.80,90.98,90.93,91.56,86.51,86.51,86.79]).reshape(-1, 3)
for i in range(len(distance)):
    data = np.array(distance[i])
    label = labels[i]
    plt.plot(data, label=label, linestyle='-' if i < 6 else '--')

plt.title("InsBank data global distance")
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1.0), borderaxespad=0.)
plt.show()

# %%
quality = np.array([5.23,5.22,5.22,5.34,5.34,5.34,5.21,5.21,5.22,5.34,5.34,5.34,5.21,5.21,5.20,5.34,5.34,5.34,5.13,5.14,5.13,5.30,5.30,5.30,5.14,5.13,5.13,5.29,5.29,5.30,5.11,5.11,5.09,5.30,5.30,5.29]).reshape(-1, 3)

for i in range(len(distance)):
    data = quality[i]
    label = labels[i]
    plt.plot(data, label=label, linestyle='-' if i < 6 else '--')

plt.title("InsBank data quality")
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1.0), borderaxespad=0.)
plt.show()
