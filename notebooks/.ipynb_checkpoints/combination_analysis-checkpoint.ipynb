# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
log = torch.load("/mnt/public02/usr/yuanpeiwen/instruction_pool_cleaned/pool_evolve/ap_logs/euclidean_multiply_alpha_0.8_lamb_0.99_momentum_fill_median_gamma_1.0_float16/0.pth")
x_values = range(log['scaled_representation_scores'].shape[0])
plt.plot(x_values, log['scaled_representation_scores'])

# %%
log = torch.load("/mnt/public02/usr/yuanpeiwen/instruction_pool_cleaned/pool_evolve/ap_logs/euclidean_multiply_alpha_0.8_lamb_0.99_momentum_fill_median_gamma_1.0_float16/1.pth")
x_values = range(log['scaled_representation_scores'].shape[0])
plt.plot(x_values, log['scaled_representation_scores'])

# %%
log = torch.load("/mnt/public02/usr/yuanpeiwen/instruction_pool_cleaned/pool_evolve/ap_logs/euclidean_multiply_alpha_0.8_lamb_0.99_momentum_fill_median_gamma_1.0_float16/2.pth")
x_values = range(log['scaled_representation_scores'].shape[0])
plt.plot(x_values, log['scaled_representation_scores'])

# %%
log = torch.load("/mnt/public02/usr/yuanpeiwen/instruction_pool_cleaned/pool_evolve/ap_logs/euclidean_multiply_alpha_0.8_lamb_0.99_momentum_fill_median_gamma_1.0_float16/3.pth")
x_values = range(log['scaled_representation_scores'].shape[0])
plt.plot(x_values, log['scaled_representation_scores'])
